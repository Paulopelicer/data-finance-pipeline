# %% [markdown]
# # 00 - Run All Pix
#
# Notebook de orquestração geral. Ele chama o executor principal e o validador pelo terminal.

# %%
from pathlib import Path
import subprocess
import sys

PROJECT_DIR = Path.cwd().resolve().parent if Path.cwd().resolve().name == "notebooks" else Path.cwd().resolve()
print(f"Projeto: {PROJECT_DIR}")

# %%
subprocess.run([sys.executable, "run_pipeline.py"], cwd=PROJECT_DIR, check=True)
subprocess.run([sys.executable, "scripts/validate_pipeline.py"], cwd=PROJECT_DIR, check=True)
