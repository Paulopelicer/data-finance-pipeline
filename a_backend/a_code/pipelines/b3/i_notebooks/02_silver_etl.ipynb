# %% [markdown]
# # 02 — Silver Layer: ETL Transformations
#
# This notebook walks through the **Silver layer** ETL pipeline.
#
# **Goal:** read raw Bronze data, apply cleansing and enrichment, validate quality,
# and write clean Parquet to the Silver store.
#
# **Silver contracts:**
# - All critical columns are non-null.
# - All prices are strictly positive.
# - No duplicate `(ticker, trade_date)` pairs.
# - `daily_return` = (close_t / close_{t-1}) − 1, per ticker.

# %%
# Configuração do notebook da camada Silver (ETL).
import sys

sys.path.insert(0, "..")

import polars as pl

pl.Config.set_tbl_rows(20)
# Out:
# polars.config.Config

# %% [markdown]
# ## 1. Read Bronze data

# %%
# 1) Leitura da camada Bronze.
# Esta é a ENTRADA do pipeline Silver: dados brutos já persistidos.
# Se a Bronze estiver vazia, o pipeline aborta sem processar nada.
from d_processing.a_bronze.ingest import read_bronze

bronze_df = read_bronze(source="yahoo_finance")
print(f"Bronze rows: {len(bronze_df):,}  |  tickers: {bronze_df['ticker'].n_unique() if not bronze_df.is_empty() else 0}")
bronze_df.head(5)
# Out:
# {"timestamp": "2026-06-28T21:01:27.823724+00:00", "level": "INFO", "logger": "d_processing.bronze.ingest", "message": "Bronze read complete", "module": "ingest", "func": "read_bronze", "line": 107, "name": "d_processing.bronze.ingest", "msg": "Bronze read complete", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "/home/efcardoso/projects/b3-data-plataform/i_notebooks/../d_processing/bronze/ingest.py", "filename": "ingest.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 107, "funcName": "read_bronze", "created": 1782680487.8236651, "msecs": 823.0, "relativeCreated": 6264.9688720703125, "thread": 133999359688832, "threadName": "MainThread", "processName": "MainProcess", "process": 72500, "taskName": "Task-42", "rows": 744, "source": "yahoo_finance"}
# Bronze rows: 744  |  tickers: 12
# shape: (5, 10)
# ┌──────────┬────────────┬───────────┬───────────┬───┬───────────┬──────────┬───────────┬───────────┐
# │ ticker   ┆ trade_date ┆ open      ┆ high      ┆ … ┆ adj_close ┆ volume   ┆ source    ┆ ingested_ │
# │ ---      ┆ ---        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---      ┆ ---       ┆ at        │
# │ str      ┆ date       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ i64      ┆ str       ┆ ---       │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ datetime[ │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ μs, UTC]  │
# ╞══════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪══════════╪═══════════╪═══════════╡
# │ PETR4.SA ┆ 2026-03-27 ┆ 48.5      ┆ 49.439999 ┆ … ┆ 47.916618 ┆ 54170900 ┆ yahoo_fin ┆ 2026-06-2 │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆ ance      ┆ 6 01:29:2 │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ 7.857039  │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ VALE3.SA ┆ 2026-03-27 ┆ 78.470001 ┆ 79.919998 ┆ … ┆ 79.0      ┆ 11101700 ┆ yahoo_fin ┆ 2026-06-2 │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆ ance      ┆ 6 01:29:2 │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ 7.857039  │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ ITUB4.SA ┆ 2026-03-27 ┆ 41.810001 ┆ 41.810001 ┆ … ┆ 41.026436 ┆ 27910700 ┆ yahoo_fin ┆ 2026-06-2 │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆ ance      ┆ 6 01:29:2 │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ 7.857039  │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ BBDC4.SA ┆ 2026-03-27 ┆ 18.709999 ┆ 18.809999 ┆ … ┆ 18.1793   ┆ 20727200 ┆ yahoo_fin ┆ 2026-06-2 │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆ ance      ┆ 6 01:29:2 │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ 7.857039  │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ ABEV3.SA ┆ 2026-03-27 ┆ 14.79     ┆ 15.0      ┆ … ┆ 14.719015 ┆ 17884700 ┆ yahoo_fin ┆ 2026-06-2 │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆ ance      ┆ 6 01:29:2 │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ 7.857039  │
# │          ┆            ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# └──────────┴────────────┴───────────┴───────────┴───┴───────────┴──────────┴───────────┴───────────┘

# %% [markdown]
# ## 2. Apply each transformation step individually

# %%
# 2a) Primeiro passo do ETL: padronização de tipos.
# - Renomeia colunas para o padrão Silver (open → open_price, etc.).
# - Garante tipos numéricos consistentes (Float64) e datas como pl.Date.
# - Normaliza o ticker (strip + uppercase).
from d_processing.b_silver.transform import (
    calculate_daily_return,
    cast_types,
    deduplicate,
    remove_invalid_prices,
    remove_nulls,
)

step1 = cast_types(bronze_df)
print("After cast_types:")
print(step1.schema)
step1.head(3)
# Out:
# After cast_types:
# Schema({'ticker': String, 'trade_date': Date, 'open': Float64, 'high': Float64, 'low': Float64, 'close': Float64, 'adj_close': Float64, 'volume': Int64, 'source': String, 'ingested_at': Datetime(time_unit='us', time_zone='UTC'), 'open_price': Float64, 'high_price': Float64, 'low_price': Float64, 'close_price': Float64})
# shape: (3, 14)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ ticker   ┆ trade_dat ┆ open      ┆ high      ┆ … ┆ open_pric ┆ high_pric ┆ low_price ┆ close_pri │
# │ ---      ┆ e         ┆ ---       ┆ ---       ┆   ┆ e         ┆ e         ┆ ---       ┆ ce        │
# │ str      ┆ ---       ┆ f64       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ f64       ┆ ---       │
# │          ┆ date      ┆           ┆           ┆   ┆ f64       ┆ f64       ┆           ┆ f64       │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ PETR4.SA ┆ 2026-03-2 ┆ 48.5      ┆ 49.439999 ┆ … ┆ 48.5      ┆ 49.439999 ┆ 48.130001 ┆ 49.41     │
# │          ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ VALE3.SA ┆ 2026-03-2 ┆ 78.470001 ┆ 79.919998 ┆ … ┆ 78.470001 ┆ 79.919998 ┆ 78.169998 ┆ 79.0      │
# │          ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ ITUB4.SA ┆ 2026-03-2 ┆ 41.810001 ┆ 41.810001 ┆ … ┆ 41.810001 ┆ 41.810001 ┆ 41.18     ┆ 41.450001 │
# │          ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# 2b) Aplicação sequencial das demais transformações da camada Silver.
# Cada etapa é uma função pura; isso facilita testes unitários (pasta z_tests).
step2 = remove_nulls(step1)             # remove linhas com nulos em colunas críticas
step3 = remove_invalid_prices(step2)    # remove linhas com preço <= 0
step4 = deduplicate(step3)              # mantém um registro por (ticker, trade_date)
step5 = calculate_daily_return(step4)   # calcula retorno diário = close_t / close_{t-1} - 1

# Auditoria simples: quantas linhas foram descartadas em cada etapa.
print("Rows after each step:")
print(f"  Bronze input  : {len(bronze_df):>7,}")
print(f"  cast_types    : {len(step1):>7,}")
print(f"  remove_nulls  : {len(step2):>7,}")
print(f"  invalid prices: {len(step3):>7,}")
print(f"  deduplicate   : {len(step4):>7,}")
print(f"  daily_return  : {len(step5):>7,}")
# Out:
# Rows after each step:
#   Bronze input  :     744
#   cast_types    :     744
#   remove_nulls  :     744
#   invalid prices:     744
#   deduplicate   :     744
#   daily_return  :     744

# %%
# 2c) Amostra do resultado final do ETL com a métrica derivada `daily_return`.
step5.select(["ticker", "trade_date", "close_price", "daily_return"]).head(15)
# Out:
# shape: (15, 4)
# ┌──────────┬────────────┬─────────────┬──────────────┐
# │ ticker   ┆ trade_date ┆ close_price ┆ daily_return │
# │ ---      ┆ ---        ┆ ---         ┆ ---          │
# │ str      ┆ date       ┆ f64         ┆ f64          │
# ╞══════════╪════════════╪═════════════╪══════════════╡
# │ ABEV3.SA ┆ 2026-03-27 ┆ 14.76       ┆ null         │
# │ ABEV3.SA ┆ 2026-03-30 ┆ 14.84       ┆ 0.00542      │
# │ ABEV3.SA ┆ 2026-03-31 ┆ 15.25       ┆ 0.027628     │
# │ ABEV3.SA ┆ 2026-04-01 ┆ 15.36       ┆ 0.007213     │
# │ ABEV3.SA ┆ 2026-04-02 ┆ 15.28       ┆ -0.005208    │
# │ ABEV3.SA ┆ 2026-04-06 ┆ 15.45       ┆ 0.011126     │
# │ ABEV3.SA ┆ 2026-04-07 ┆ 15.48       ┆ 0.001942     │
# │ ABEV3.SA ┆ 2026-04-08 ┆ 15.86       ┆ 0.024548     │
# │ ABEV3.SA ┆ 2026-04-09 ┆ 16.059999   ┆ 0.01261      │
# │ ABEV3.SA ┆ 2026-04-10 ┆ 16.120001   ┆ 0.003736     │
# │ ABEV3.SA ┆ 2026-04-13 ┆ 15.93       ┆ -0.011787    │
# │ ABEV3.SA ┆ 2026-04-14 ┆ 15.89       ┆ -0.002511    │
# │ ABEV3.SA ┆ 2026-04-15 ┆ 15.83       ┆ -0.003776    │
# │ ABEV3.SA ┆ 2026-04-16 ┆ 15.43       ┆ -0.025268    │
# │ ABEV3.SA ┆ 2026-04-17 ┆ 15.33       ┆ -0.006481    │
# └──────────┴────────────┴─────────────┴──────────────┘

# %% [markdown]
# ## 3. Run quality checks

# %%
# 3) Quality Gates: testes fail-fast sobre o DataFrame transformado.
# Garante o "contrato" da camada Silver:
#   - colunas-chave sem nulos
#   - preços positivos
#   - sem duplicatas (ticker, trade_date)
#   - sem datas no futuro
# Se qualquer asserção falhar, o pipeline aborta — não gravamos lixo na Silver.
from e_validation.quality_checks import run_silver_quality_checks

validated = run_silver_quality_checks(step5)
print("✔  All quality checks passed")
# Out:
# {"timestamp": "2026-06-26T01:34:07.581776+00:00", "level": "INFO", "logger": "e_validation.quality_checks", "message": "Running Silver quality checks", "module": "quality_checks", "func": "run_silver_quality_checks", "line": 48, "name": "e_validation.quality_checks", "msg": "Running Silver quality checks", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\e_validation\\quality_checks.py", "filename": "quality_checks.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 48, "funcName": "run_silver_quality_checks", "created": 1782437647.5817342, "msecs": 581.0, "relativeCreated": 188292.7973, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-159", "rows": 720}
# {"timestamp": "2026-06-26T01:34:07.595646+00:00", "level": "INFO", "logger": "e_validation.quality_checks", "message": "All Silver quality checks passed", "module": "quality_checks", "func": "run_silver_quality_checks", "line": 55, "name": "e_validation.quality_checks", "msg": "All Silver quality checks passed", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\e_validation\\quality_checks.py", "filename": "quality_checks.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 55, "funcName": "run_silver_quality_checks", "created": 1782437647.595598, "msecs": 595.0, "relativeCreated": 188306.6611, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-159"}
# ✔  All quality checks passed

# %% [markdown]
# ## 4. Write to Silver and verify

# %%
# 4) Persistência: escreve a Silver e relê para confirmar.
# `transform_silver` encapsula todo o encadeamento de transformações acima.
from d_processing.b_silver.transform import read_silver, transform_silver, write_silver

silver_clean = transform_silver(bronze_df)
write_silver(silver_clean)

silver_df = read_silver()
print(f"Silver rows: {len(silver_df):,}")
silver_df.head(10)
# Out:
# {"timestamp": "2026-06-26T01:34:15.634371+00:00", "level": "INFO", "logger": "d_processing.silver.transform", "message": "Silver write complete", "module": "transform", "func": "write_silver", "line": 161, "name": "d_processing.silver.transform", "msg": "Silver write complete", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\d_processing\\silver\\transform.py", "filename": "transform.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 161, "funcName": "write_silver", "created": 1782437655.6342983, "msecs": 634.0, "relativeCreated": 196345.3615, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-174", "rows": 720, "partitions": 60, "output": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\j_data\\silver"}
# {"timestamp": "2026-06-26T01:34:18.232560+00:00", "level": "INFO", "logger": "d_processing.silver.transform", "message": "Silver read complete", "module": "transform", "func": "read_silver", "line": 187, "name": "d_processing.silver.transform", "msg": "Silver read complete", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\d_processing\\silver\\transform.py", "filename": "transform.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 187, "funcName": "read_silver", "created": 1782437658.232505, "msecs": 232.0, "relativeCreated": 198943.5683, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-174", "rows": 720}
# Silver rows: 720
# shape: (10, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬──────────┬───────────┬───────────┐
# │ ticker    ┆ trade_dat ┆ open_pric ┆ high_pric ┆ … ┆ adj_close ┆ volume   ┆ daily_ret ┆ processed │
# │ ---       ┆ e         ┆ e         ┆ e         ┆   ┆ ---       ┆ ---      ┆ urn       ┆ _at       │
# │ str       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ f64       ┆ i64      ┆ ---       ┆ ---       │
# │           ┆ date      ┆ f64       ┆ f64       ┆   ┆           ┆          ┆ f64       ┆ datetime[ │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ μs, UTC]  │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪══════════╪═══════════╪═══════════╡
# │ ABEV3.SA  ┆ 2026-03-2 ┆ 14.79     ┆ 15.0      ┆ … ┆ 14.719015 ┆ 17884700 ┆ null      ┆ 2026-06-2 │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6 01:34:1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 1.200446  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ BBAS3.SA  ┆ 2026-03-2 ┆ 22.99     ┆ 22.99     ┆ … ┆ 22.500587 ┆ 16957900 ┆ null      ┆ 2026-06-2 │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6 01:34:1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 1.200446  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ BBDC4.SA  ┆ 2026-03-2 ┆ 18.709999 ┆ 18.809999 ┆ … ┆ 18.1793   ┆ 20727200 ┆ null      ┆ 2026-06-2 │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6 01:34:1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 1.200446  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ BPAC11.SA ┆ 2026-03-2 ┆ 54.77     ┆ 54.779999 ┆ … ┆ 53.529999 ┆ 14128200 ┆ null      ┆ 2026-06-2 │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6 01:34:1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 1.200446  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ ITUB4.SA  ┆ 2026-03-2 ┆ 41.810001 ┆ 41.810001 ┆ … ┆ 41.026436 ┆ 27910700 ┆ null      ┆ 2026-06-2 │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6 01:34:1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 1.200446  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ LREN3.SA  ┆ 2026-03-2 ┆ 15.11     ┆ 15.26     ┆ … ┆ 14.655182 ┆ 25661200 ┆ null      ┆ 2026-06-2 │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6 01:34:1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 1.200446  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ MGLU3.SA  ┆ 2026-03-2 ┆ 8.41      ┆ 8.45      ┆ … ┆ 8.01463   ┆ 22237700 ┆ null      ┆ 2026-06-2 │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6 01:34:1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 1.200446  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ PETR4.SA  ┆ 2026-03-2 ┆ 48.5      ┆ 49.439999 ┆ … ┆ 47.916618 ┆ 54170900 ┆ null      ┆ 2026-06-2 │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6 01:34:1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 1.200446  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ RADL3.SA  ┆ 2026-03-2 ┆ 23.549999 ┆ 23.66     ┆ … ┆ 23.208319 ┆ 4994500  ┆ null      ┆ 2026-06-2 │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6 01:34:1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 1.200446  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# │ RENT3.SA  ┆ 2026-03-2 ┆ 45.75     ┆ 45.779999 ┆ … ┆ 44.627884 ┆ 9079900  ┆ null      ┆ 2026-06-2 │
# │           ┆ 7         ┆           ┆           ┆   ┆           ┆          ┆           ┆ 6 01:34:1 │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ 1.200446  │
# │           ┆           ┆           ┆           ┆   ┆           ┆          ┆           ┆ UTC       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴──────────┴───────────┴───────────┘

# %% [markdown]
# ## 5. Visualize daily returns

# %%
# 5a) Visualização: série temporal dos retornos diários dos 5 ativos demo.
# Linha horizontal no zero serve como referência (acima = alta, abaixo = baixa).
import plotly.express as px
import plotly.io as pio

pio.templates.default = "plotly_white"

top5 = ["PETR4.SA", "VALE3.SA", "ITUB4.SA", "BBDC4.SA", "ABEV3.SA"]
plot_df = silver_df.filter(pl.col("ticker").is_in(top5)).sort("trade_date").to_pandas()

fig = px.line(
    plot_df,
    x="trade_date",
    y="daily_return",
    color="ticker",
    title="Retorno Diário das Ações da B3 — Camada Silver",
    labels={
        "trade_date": "Data da Negociação",
        "daily_return": "Retorno Diário",
        "ticker": "Ativo",
    },
)
fig.add_hline(y=0, line_dash="dash", line_color="grey", annotation_text="0%", annotation_position="top left")
fig.update_layout(
    height=500,
    hovermode="x unified",
    legend=dict(title="Ativo", orientation="v", x=1.02, y=1),
    margin=dict(l=60, r=40, t=70, b=50),
)
fig.update_yaxes(tickformat=".2%")
fig.update_xaxes(tickformat="%d/%m/%Y")
fig.show()

# %%
# 5b) Distribuição dos retornos diários (histograma).
# Sobreposição (`barmode="overlay"`) facilita comparar a dispersão entre ativos.
fig2 = px.histogram(
    plot_df.dropna(subset=["daily_return"]),
    x="daily_return",
    color="ticker",
    nbins=60,
    title="Distribuição dos Retornos Diários por Ativo",
    barmode="overlay",
    opacity=0.55,
    labels={
        "daily_return": "Retorno Diário",
        "ticker": "Ativo",
        "count": "Frequência",
    },
)
fig2.update_layout(
    height=480,
    legend=dict(title="Ativo"),
    margin=dict(l=60, r=40, t=70, b=50),
    yaxis_title="Frequência",
)
fig2.update_xaxes(tickformat=".1%")
fig2.show()

# %% [markdown]
# ## 6. Run full Silver pipeline

# %%
# 6) Execução do pipeline Silver via classe (mesmo objeto usado pelo Airflow).
# `SilverPipeline.run()` faz: read_bronze → transform_silver → quality_checks → write_silver.
from lab_vacation260625.b3_data_plataform_ezequiel_fc.f_pipelines.b_silver_pipeline import (
    SilverPipeline,
)

result = SilverPipeline().run()
print(f"SilverPipeline produced {len(result):,} clean rows")
# Out:
# {"timestamp": "2026-06-26T01:36:25.969496+00:00", "level": "INFO", "logger": "f_pipelines.silver_pipeline", "message": "SilverPipeline started", "module": "silver_pipeline", "func": "run", "line": 53, "name": "f_pipelines.silver_pipeline", "msg": "SilverPipeline started", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\f_pipelines\\silver_pipeline.py", "filename": "silver_pipeline.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 53, "funcName": "run", "created": 1782437785.969467, "msecs": 969.0, "relativeCreated": 326680.5301, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-195"}
# {"timestamp": "2026-06-26T01:36:25.970424+00:00", "level": "INFO", "logger": "f_pipelines.silver_pipeline", "message": "Reading Bronze data", "module": "silver_pipeline", "func": "extract", "line": 39, "name": "f_pipelines.silver_pipeline", "msg": "Reading Bronze data", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\f_pipelines\\silver_pipeline.py", "filename": "silver_pipeline.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 39, "funcName": "extract", "created": 1782437785.9703918, "msecs": 970.0, "relativeCreated": 326681.4548, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-195", "source": "yahoo_finance", "date": null}
# {"timestamp": "2026-06-26T01:36:28.260607+00:00", "level": "INFO", "logger": "d_processing.bronze.ingest", "message": "Bronze read complete", "module": "ingest", "func": "read_bronze", "line": 107, "name": "d_processing.bronze.ingest", "msg": "Bronze read complete", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\d_processing\\bronze\\ingest.py", "filename": "ingest.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 107, "funcName": "read_bronze", "created": 1782437788.2605462, "msecs": 260.0, "relativeCreated": 328971.6095, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-195", "rows": 720, "source": "yahoo_finance"}
# {"timestamp": "2026-06-26T01:36:28.262044+00:00", "level": "INFO", "logger": "f_pipelines.silver_pipeline", "message": "Applying Silver transformations", "module": "silver_pipeline", "func": "transform", "line": 43, "name": "f_pipelines.silver_pipeline", "msg": "Applying Silver transformations", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\f_pipelines\\silver_pipeline.py", "filename": "silver_pipeline.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 43, "funcName": "transform", "created": 1782437788.2620063, "msecs": 262.0, "relativeCreated": 328973.0695, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-195", "input_rows": 720}
# {"timestamp": "2026-06-26T01:36:28.271071+00:00", "level": "INFO", "logger": "e_validation.quality_checks", "message": "Running Silver quality checks", "module": "quality_checks", "func": "run_silver_quality_checks", "line": 48, "name": "e_validation.quality_checks", "msg": "Running Silver quality checks", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\e_validation\\quality_checks.py", "filename": "quality_checks.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 48, "funcName": "run_silver_quality_checks", "created": 1782437788.2710214, "msecs": 271.0, "relativeCreated": 328982.0845, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-195", "rows": 720}
# {"timestamp": "2026-06-26T01:36:28.273243+00:00", "level": "INFO", "logger": "e_validation.quality_checks", "message": "All Silver quality checks passed", "module": "quality_checks", "func": "run_silver_quality_checks", "line": 55, "name": "e_validation.quality_checks", "msg": "All Silver quality checks passed", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\e_validation\\quality_checks.py", "filename": "quality_checks.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 55, "funcName": "run_silver_quality_checks", "created": 1782437788.2731934, "msecs": 273.0, "relativeCreated": 328984.2565, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-195"}
# {"timestamp": "2026-06-26T01:36:28.274503+00:00", "level": "INFO", "logger": "f_pipelines.silver_pipeline", "message": "Transformation complete", "module": "silver_pipeline", "func": "transform", "line": 46, "name": "f_pipelines.silver_pipeline", "msg": "Transformation complete", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\f_pipelines\\silver_pipeline.py", "filename": "silver_pipeline.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 46, "funcName": "transform", "created": 1782437788.274457, "msecs": 274.0, "relativeCreated": 328985.5201, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-195", "output_rows": 720}
# {"timestamp": "2026-06-26T01:36:32.157089+00:00", "level": "INFO", "logger": "d_processing.silver.transform", "message": "Silver write complete", "module": "transform", "func": "write_silver", "line": 161, "name": "d_processing.silver.transform", "msg": "Silver write complete", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\d_processing\\silver\\transform.py", "filename": "transform.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 161, "funcName": "write_silver", "created": 1782437792.157034, "msecs": 157.0, "relativeCreated": 332868.0971, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-195", "rows": 720, "partitions": 60, "output": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\j_data\\silver"}
# {"timestamp": "2026-06-26T01:36:32.158073+00:00", "level": "INFO", "logger": "f_pipelines.silver_pipeline", "message": "SilverPipeline finished", "module": "silver_pipeline", "func": "run", "line": 60, "name": "f_pipelines.silver_pipeline", "msg": "SilverPipeline finished", "args": [], "levelname": "INFO", "levelno": 20, "pathname": "\\\\wsl.localhost\\ubuntu-llm\\home\\efcardoso\\projects\\b3-data-plataform\\i_notebooks\\..\\f_pipelines\\silver_pipeline.py", "filename": "silver_pipeline.py", "exc_info": null, "exc_text": null, "stack_info": null, "lineno": 60, "funcName": "run", "created": 1782437792.1580374, "msecs": 158.0, "relativeCreated": 332869.1006, "thread": 27016, "threadName": "MainThread", "processName": "MainProcess", "process": 19984, "taskName": "Task-195", "rows": 720}
# SilverPipeline produced 720 clean rows
